# %%
from pytrends.request import TrendReq

pytrend = TrendReq()

kw_list = ['Hi', 'Hello']

df = pytrend.get_historical_interest(kw_list, year_start=2018, month_start=1, day_start=1, hour_start=0, year_end=2018, month_end=2, day_end=1, hour_end=0, cat=0, geo='', gprop='', sleep=0)

# %%
df.max().idxmax()
# Out:
# 'Hi'

# %%
df.max()
# Out:
# Hi           100.0
# Hello         97.0
# isPartial      0.0
# dtype: float64

# %%
import time
import pandas as pd


def get_most_popular(keyword_list):
    pytrend = TrendReq()
    df = pytrend.get_historical_interest(keyword_list,
                                         year_start=2018,
                                         month_start=1,
                                         day_start=1,
                                         hour_start=0,
                                         year_end=2018,
                                         month_end=2,
                                         day_end=1,
                                         hour_end=0,
                                         cat=0,
                                         geo='',
                                         gprop='',
                                         sleep=0)
    return df, df.max().idxmax()


def get_most_popular_against(keyword_list, most_popular):
    
    if len(keyword_list) == 0:
        return None
    
    keyword_list_copy = list(keyword_list)
    
    result = []
    
    while len(keyword_list_copy) != 0:
        temp = [keyword_list_copy.pop() for i in range(min(4, len(keyword_list_copy)))]
        df_temp, _ = get_most_popular(temp)
        result.append(df_temp)
    
    
    
    df1 = result[0]
    for df in result[1:]:
        df1 = pd.merge(df1, df, on=list(set(df.columns).intersection(set(df1.columns))))
        
    return df1
    

def blah(keyword_list):
    
    #dic = {keyword:None for keyword in keyword_list}
        
        
    cache = []
    
    
    keyword_list_copy = list(keyword_list)
    current_most_popular = None

    while len(keyword_list_copy) > 1:
        current_five = [keyword_list_copy.pop() for i in range(min(5, len(keyword_list_copy)))]
        
        df, new_most_popular = get_most_popular(current_five)
        
        if new_most_popular != current_most_popular:
            cache = [(df, new_most_popular)]
        else:
            cache.append((df, new_most_popular))
        
        current_most_popular = new_most_popular
        
        keyword_list_copy.append(current_most_popular)
        print(f'Current most popular is {current_most_popular} among {current_five}')
    
    
    keywords_we_have = set()
    for df, popular in cache:
        for column in df.columns[1:-1]:
            keywords_we_have.add(column)
            
    keywords_to_get = set(keyword_list_copy) - keywords_we_have
    
    df1 = None
    
    thing = get_most_popular_against(keywords_to_get, current_most_popular)
    if thing is not None:
        df1 = thing
    else:
        df1, _ = cache[0]
    
    for df, _ in cache:
        df1 = pd.merge(df1, df, on=list(set(df.columns).intersection(set(df1.columns))))

    return df1.drop('isPartial', axis=1)

# %%
kw_list = ['Hi', 'Hello', 'Java', 'Ed Sheeran', 'Jupyter', 'Kardashian',
           'Trump', 'Mozilla', 'Llusx', 'Obama', 'Germany', 'France', 'Mouse',
           'Wallet', 'Keys', 'Mug', 'Paper', 'Speakers', 'Book', 'Table']
df = blah(kw_list)
# Out:
# Current most popular is Table among ['Table', 'Book', 'Speakers', 'Paper', 'Mug']
# Current most popular is Table among ['Table', 'Keys', 'Wallet', 'Mouse', 'France']
# Current most popular is Table among ['Table', 'Germany', 'Obama', 'Llusx', 'Mozilla']
# Current most popular is Table among ['Table', 'Trump', 'Kardashian', 'Jupyter', 'Ed Sheeran']
# Current most popular is Table among ['Table', 'Java', 'Hello', 'Hi']
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-131-729e520aff4d> in <module>()
#       2            'Trump', 'Mozilla', 'Llusx', 'Obama', 'Germany', 'France', 'Mouse',
#       3            'Wallet', 'Keys', 'Mug', 'Paper', 'Speakers', 'Book', 'Table']
# ----> 4 df = blah(kw_list)
#
# <ipython-input-130-59c6947e0983> in blah(keyword_list)
#      87
#      88     for df, _ in cache:
# ---> 89         df1 = pd.merge(df1, df, on=list(set(df.columns).intersection(set(df1.columns))))
#      90
#      91     return df1.drop('isPartial', axis=1)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      59                          copy=copy, indicator=indicator,
#      60                          validate=validate)
# ---> 61     return op.get_result()
#      62
#      63
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/reshape/merge.py in get_result(self)
#     579             [(ldata, lindexers), (rdata, rindexers)],
#     580             axes=[llabels.append(rlabels), join_index],
# --> 581             concat_axis=0, copy=self.copy)
#     582
#     583         typ = self.left._constructor
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals.py in concatenate_block_managers(mgrs_indexers, axes, concat_axis, copy)
#    5419         else:
#    5420             b = make_block(
# -> 5421                 concatenate_join_units(join_units, concat_axis, copy=copy),
#    5422                 placement=placement)
#    5423         blocks.append(b)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals.py in concatenate_join_units(join_units, concat_axis, copy)
#    5563     to_concat = [ju.get_reindexed_values(empty_dtype=empty_dtype,
#    5564                                          upcasted_na=upcasted_na)
# -> 5565                  for ju in join_units]
#    5566
#    5567     if len(to_concat) == 1:
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals.py in <listcomp>(.0)
#    5563     to_concat = [ju.get_reindexed_values(empty_dtype=empty_dtype,
#    5564                                          upcasted_na=upcasted_na)
# -> 5565                  for ju in join_units]
#    5566
#    5567     if len(to_concat) == 1:
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals.py in get_reindexed_values(self, empty_dtype, upcasted_na)
#    5873             for ax, indexer in self.indexers.items():
#    5874                 values = algos.take_nd(values, indexer, axis=ax,
# -> 5875                                        fill_value=fill_value)
#    5876
#    5877         return values
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/algorithms.py in take_nd(arr, indexer, axis, out, fill_value, mask_info, allow_fill)
#    1650             out = np.empty(out_shape, dtype=dtype, order='F')
#    1651         else:
# -> 1652             out = np.empty(out_shape, dtype=dtype)
#    1653
#    1654     func = _get_take_nd_function(arr.ndim, arr.dtype, out.dtype, axis=axis,
#
# MemoryError:

# %%
import matplotlib.pylab as plt
import matplotlib.dates as mdates

my_fmt = mdates.DateFormatter('%d-%m-%y')

fig = plt.figure(figsize=(16, 8))
ax = plt.axes()

ax.set_xlabel('Time')
ax.set_ylabel('Popularity')
ax.xaxis.set_major_formatter(my_fmt)

# Aesthetics
ax.spines["top"].set_visible(False) 
ax.spines["right"].set_visible(False)

for column in df.columns[1:]:
    plt.plot(df[column][-52:])
    
ax.legend(list(df.columns[1:]))

for tick in ax.get_xticklabels():
    tick.set_rotation(45)

plt.show()

# %%
fig = plt.figure(figsize=(16, 8))
ax = plt.axes()

width = 0.35

sli = df.iloc[104:]

keywords = ['Hi', 'Hello', 'Java', 'Ed Sheeran', 'Jupyter', 'Kardashian', 'Trump', 'Mozilla', 'Llusx']

rects = []
for i, keyword in enumerate(keywords):
    rects.append(ax.bar(i * width, sli[keyword].mean(), width))

ax.set_ylabel('Popularity')
ax.set_xticks([-1])

ax.legend(rects, df.columns[1:])
